# %%
import random

#Setting the seed
random.seed(1991)

#function for rolling the dice
def Roll1(n1):
    """This function simulates rolling a dice for n-times"""
    
    #Empty vector to store the result of dice roll
    result1 = []
    
    for i in range(1,n1+1):
        result1.append(random.choice([1, 2, 3, 4, 5, 6]))
    return result1

def Roll2(n2):
    """This function simulates rolling a dice for n-times"""
    
    #Empty vector to store the result of dice roll
    result2 = []
    
    for i in range(1,n2+1):
        result2.append(random.choice([1, 2, 3, 4, 5, 6]))
    return result2

def Roll3(n3):
    """This function simulates rolling a dice for n-times"""
    
    #Empty vector to store the result of dice roll
    result3 = []
    
    for i in range(1,n3+1):
        result3.append(random.choice([1, 2, 3, 4, 5, 6]))
    return result3


def Roll4(n4):
    """This function simulates rolling a dice for n-times"""
    
    #Empty vector to store the result of dice roll
    result4 = []
    
    for i in range(1,n4+1):
        result4.append(random.choice([1, 2, 3, 4, 5, 6]))
    return result4

def Roll5(n5):
    """This function simulates rolling a dice for n-times"""
    
    #Empty vector to store the result of dice roll
    result5 = []
    
    for i in range(1,n5+1):
        result5.append(random.choice([1, 2, 3, 4, 5, 6]))
    return result5


def calculate_mean1(number):
  s=sum(result1)
  N=len(result1)
# Calculate the mean
  mean1=s/N
  return mean1

def calculate_mean2(number):
  s=sum(result2)
  N=len(result2)
# Calculate the mean
  mean2=s/N
  return mean2

def calculate_mean3(number):
  s=sum(result3)
  N=len(result3)
# Calculate the mean
  mean3=s/N
  return mean3

def calculate_mean4(number):
  s=sum(result4)
  N=len(result4)
# Calculate the mean
  mean4=s/N
  return mean4

def calculate_mean5(number):
  s=sum(result5)
  N=len(result5)
# Calculate the mean
  mean5=s/N
  return mean4

#roll the dice 
result1 = Roll1(100)
result2 = Roll2(1000)
result3 = Roll3(10000)
result4 = Roll4(100000)
result5 = Roll5(500000)


#averages
if __name__=='__main__':
   donations = []
   mean1=calculate_mean1(result1)
   mean2=calculate_mean2(result2)
   mean3=calculate_mean3(result3)
   mean4=calculate_mean4(result4)
   mean5=calculate_mean5(result5)

   print(mean1)
   print(mean2)
   print(mean3)
   print(mean4)
   print(mean5)
# Out:
# 3.44
# 3.446
# 3.496
# 3.50743
# 3.50743

# %%
#Roll a die until the total score is 20


import random
#target_score=100
target_num_rolls=100

def roll():
  return random.randint(1,6)

def calculate_mean(numbers):
  s=sum(numbers)
  N=len(numbers)
# Calculate the mean
  mean=s/N

  return mean


if __name__=='__main__':
  score=0
  num_rolls=0
  while 100<target_num_rolls:
    die_roll=roll()
    num_rolls+=1
    print('Rolled:{0}'.format(die_roll))
    score+=die_roll
  print('Score of {0} reached in {1} rolls'.format(score, num_rolls))
# Out:
# Rolled:5
# Rolled:6
# Rolled:1
# Rolled:1
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:3
# Rolled:6
# Rolled:2
# Rolled:4
# Rolled:2
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:6
# Rolled:2
# Rolled:3
# Rolled:4
# Rolled:2
# Rolled:6
# Rolled:2
# Rolled:5
# Score of 100 reached in 25 rolls

# %%
#Roll a die until the total score is 20


import random
#target_score=100
target_num_rolls=100

def roll():
  return random.randint(1,6)

def calculate_mean(numbers):
  s=sum(numbers)
  N=len(numbers)
# Calculate the mean
  mean=s/N

  return mean


if __name__=='__main__':
  score=0
  num_rolls=0
  while 100<target_num_rolls:
    die_roll=roll()
    num_rolls+=1
    print('Rolled:{0}'.format(die_roll))
    score+=die_roll
  print('Score of {0} reached in {1} rolls'.format(score, num_rolls))
# Out:
# Rolled:5
# Rolled:6
# Rolled:1
# Rolled:1
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:3
# Rolled:6
# Rolled:2
# Rolled:4
# Rolled:2
# Rolled:5
# Rolled:5
# Rolled:5
# Rolled:6
# Rolled:2
# Rolled:3
# Rolled:4
# Rolled:2
# Rolled:6
# Rolled:2
# Rolled:5
# Score of 100 reached in 25 rolls
